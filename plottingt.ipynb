# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use("seaborn")

# %%
df = pd.read_csv("log.csv")

# %%
df
# Out:
#    time  omega_d  omega  torque
# 0     0       10      0      10
# 1     1       10     10      10

# %%
df.plot('time', ['omega', 'omega_d'])
