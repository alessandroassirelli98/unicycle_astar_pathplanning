# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use("seaborn")

# %%
df = pd.read_csv("Log.csv", sep=" ", decimal=",")

# %%
df
# Out:
#              time  omega_ref     omega  alpha_ref  Unnamed: 4  fwd
# 0        229.3148          2  0.000000 -71.457630    0.000000  NaN
# 1        231.1426          2 -1.018317 -71.456670    0.009718  NaN
# 2        232.9773          2 -1.018317 -71.456670    0.009718  NaN
# 3        234.8189          2  1.229718 -71.449360    0.027392  NaN
# 4        236.6670          2  1.229718 -71.449360    0.027392  NaN
# ...           ...        ...       ...        ...         ...  ...
# 6018  113500.5000         10  9.960682  -0.237238    1.000819  NaN
# 6019  113532.0000         10  9.958973  -0.235681    1.000214  NaN
# 6020  113563.5000         10  9.958973  -0.235681    1.000214  NaN
# 6021  113595.0000         10  9.958973  -0.235681    1.000214  NaN
# 6022  113626.5000         10  9.958973  -0.200000         NaN  NaN
#
# [6023 rows x 6 columns]

# %%
since = 0
to = -1
plt.plot(df['time'][since:to], df['omega_ref'][since:to])
plt.plot(df['time'][since:to], df['omega'][since:to])
plt.legend(["target", "real"])
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
plt.plot(df['time'][since:to], df['alpha_ref'][since:to])
plt.legend(["real", "target"])

# %%
since = 0
to = 5000
plt.plot(df['time'][since:to], df['fwd'][since:to])
